# %% [markdown]
# <a href="https://colab.research.google.com/github/hyevvon/ESAA/blob/main/OB%2025-2/Assignment/251003_CHAPTER8_TextAnalytics_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [개념 필사] - 파머완

# %% [markdown]
# ## CHAPTER 08 <텍스트 분석>
#
# ## **8.7 문서 군집화 소개와 실습**
#
#
# ◾**문서 군집화** : 비슷한 텍스트 구성의 문서를 군집화하는 것. 텍스트 문서 분류의 비지도학습.
#
#
# > 🟠 Opinion Review 🟠
#
# (1) 데이터 로드
#
# (2) TF-IDF 피처 벡터화
#
# * TfidfVectorizer에서 어근 변환 수행하는 LemNormalize() 함수 (tokenizer 인자에 해당 커스텀 함수 지정)
#
# (3) K-평균 군집화
#
# > ◾군집별 핵심 단어 추출하기
#
# ```
# clusters_centers_ - 각 군집의 단어가 각 군집의 중심으로부터 얼마나 가깝게 위치해있는지 / 행은 개별 군집, 열은 개별 피처
# ```
# * 각 배열값 = 각 피처의 위치가 개별 중심과 얼마나 가까운가를 상대 값으로 나타낸 것. 1에 가까울수록 중심과 가까움.
#
#
# ```
# argsort()[:,::-1] - 배열 내 값이 큰 순으로 정렬된 위치 인덱스값 반환
# ```
# * 핵심 단어 인덱스값을 사용하여 핵심 단어 이름(+alpha) 추출하는 get_cluster_details() 함수
# ✅ (입력인자) KMeans군집화객체, document_df 데이터프레임, 피처명 리스트, 전체 군집 개수, 핵심 단어 추출 개수
#
# * get_cluster_details()로 출력되는 정보를 더 보기 좋게 표현하기 위한 print_cluster_details() 함수

# %% [markdown]
# # [코드 필사]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import glob, os
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 700)

path = r'/content/drive/MyDrive/Colab Notebooks/data/topics'
all_files = glob.glob(os.path.join(path,"*.data"))
filename_list = []
opinion_text = []

for file_ in all_files:
  df = pd.read_table(file_, index_col=None, header=0, encoding='latin1')
  filename_ = file_.split('/')[-1]
  filename = filename_.split('.')[0]
  filename_list.append(filename)
  opinion_text.append(df.to_string())

document_df = pd.DataFrame({'filename':filename_list, 'opinion_text':opinion_text})
document_df.head()
# Out:
#                      filename  \
# 0  voice_garmin_nuvi_255W_gps
# 1        screen_ipod_nano_8gb
# 2     food_holiday_inn_london
# 3         fonts_amazon_kindle
# 4  interior_toyota_camry_2007
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

def LemNormalize(text):
  lemmatizer = WordNetLemmatizer()
  return [lemmatizer.lemmatize(token) for token in word_tokenize(text)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english',
                             ngram_range=(1,2), min_df=0.05, max_df=0.85)

# opinion_text 칼럼값으로 피처 벡터화 수행
feature_vect = tfidf_vect.fit_transform(document_df['opinion_text'])

# %%
## 군집화 수행
from sklearn.cluster import KMeans

# 5개 집합으로 군집화 수행, 예제를 위해 동일한 클러스터링 결과 도출영 random_state=0
km_cluster = KMeans(n_clusters=5, max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

# %%
## cluster_label로 추가해 확인
document_df['cluster_label'] = cluster_label
document_df.head()
# Out:
#                      filename  \
# 0  voice_garmin_nuvi_255W_gps
# 1        screen_ipod_nano_8gb
# 2     food_holiday_inn_london
# 3         fonts_amazon_kindle
# 4  interior_toyota_camry_2007
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==0].sort_values(by='filename')
# Out:
#                          filename  \
# 34          buttons_amazon_kindle
# 38  eyesight-issues_amazon_kindle
# 3             fonts_amazon_kindle
# 45       navigation_amazon_kindle
# 27            price_amazon_kindle
# 48       price_holiday_inn_london
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# ...

# %%
document_df[document_df['cluster_label']==1].sort_values(by='filename')
# Out:
#                            filename  \
# 9    bathroom_bestwestern_hotel_sfo
# 2           food_holiday_inn_london
# 11           food_swissotel_chicago
# 17       free_bestwestern_hotel_sfo
# 31   location_bestwestern_hotel_sfo
# 23      location_holiday_inn_london
# 40    parking_bestwestern_hotel_sfo
# 37          room_holiday_inn_london
# 19      rooms_bestwestern_hotel_sfo
# 28          rooms_swissotel_chicago
# 36    service_bestwestern_hotel_sfo
# 39       service_holiday_inn_london
# 41  service_swissotel_hotel_chicago
# 32      staff_bestwestern_hotel_sfo
# 13          staff_swissotel_chicago
#
# ...

# %%
document_df[document_df['cluster_label']==2].sort_values(by='filename')
# Out:
#                           filename  \
# 50       comfort_honda_accord_2008
# 12       comfort_toyota_camry_2007
# 44   gas_mileage_toyota_camry_2007
# 15      interior_honda_accord_2008
# 4       interior_toyota_camry_2007
# 6        mileage_honda_accord_2008
# 20   performance_honda_accord_2008
# 35      performance_netbook_1005ha
# 42       quality_toyota_camry_2007
# 29         seats_honda_accord_2008
# 14                  speed_windows7
# 43  transmission_toyota_camry_2007
#
# ...

# %%
document_df[document_df['cluster_label']==3].sort_values(by='filename')
# Out:
#                        filename  \
# 49   battery-life_amazon_kindle
# 46   battery-life_ipod_nano_8gb
# 47  battery-life_netbook_1005ha
# 24      keyboard_netbook_1005ha
# 1          screen_ipod_nano_8gb
# 26        screen_netbook_1005ha
# 25     size_asus_netbook_1005ha
# 18          sound_ipod_nano_8gb
# 7           video_ipod_nano_8gb
#
# ...

# %%
document_df[document_df['cluster_label']==4].sort_values(by='filename')
# Out:
#                            filename  \
# 30    accuracy_garmin_nuvi_255W_gps
# 22  directions_garmin_nuvi_255W_gps
# 10     display_garmin_nuvi_255W_gps
# 16                features_windows7
# 8    satellite_garmin_nuvi_255W_gps
# 5       screen_garmin_nuvi_255W_gps
# 33       speed_garmin_nuvi_255W_gps
# 21     updates_garmin_nuvi_255W_gps
# 0        voice_garmin_nuvi_255W_gps
#
# ...

# %%
# k=3 으로 다시 수행
from sklearn.cluster import KMeans

# 3개 집합으로 군집화 수행
km_cluster = KMeans(n_clusters=3,max_iter=10000, random_state=0)
km_cluster.fit(feature_vect)
cluster_label = km_cluster.labels_

document_df['cluster_label'] = cluster_label
document_df.sort_values(by='cluster_label')
# Out:
#                            filename  \
# 0        voice_garmin_nuvi_255W_gps
# 1              screen_ipod_nano_8gb
# 3               fonts_amazon_kindle
# 5       screen_garmin_nuvi_255W_gps
# 7               video_ipod_nano_8gb
# 8    satellite_garmin_nuvi_255W_gps
# 10     display_garmin_nuvi_255W_gps
# 16                features_windows7
# 24          keyboard_netbook_1005ha
# 25         size_asus_netbook_1005ha
# 26            screen_netbook_1005ha
# 27              price_amazon_kindle
# 30    accuracy_garmin_nuvi_255W_gps
# 22  directions_garmin_nuvi_255W_gps
# 21     updates_garmin_nuvi_255W_gps
# 33       speed_garmin_nuvi_255W_gps
# 46       battery-life_ipod_nano_8gb
# 49       battery-life_amazon_kindle
# 45         navigation_amazon_kindle
# 47      battery-life_netbook_1005ha
# 34            buttons_amazon_kindle
# 38    eyesight-issues_amazon_kindle
# 17       free_bestwestern_hotel_sfo
# 13          staff_swissotel_chicago
# 37          room_holiday_inn_london
# ...

# %%
cluster_centers = km_cluster.cluster_centers_
print('cluster_centers shape : ', cluster_centers.shape)
print(cluster_centers)
# Out:
# cluster_centers shape :  (3, 6155)
# [[0.00185368 0.00136302 0.         ... 0.         0.         0.        ]
#  [0.         0.00040956 0.00090396 ... 0.00175541 0.00139053 0.00139053]
#  [0.         0.         0.         ... 0.         0.         0.        ]]

# %%
# 군집별 top n 핵심 단어, 그 단어의 중심 위치 상댓값, 대상 파일명 반환
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num, top_n_features=10):
  cluster_details = {}

  # cluster_centers array의 값이 큰 순으로 정렬된 인덱스 값 반환
  # 센트로이드 별 할당된 워드 피처들의 거리값이 큰 순으로 값을 구하기 위함
  centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:,::-1]

  # 개별 군집별로 반복하며 핵심 단어, 중심 위치 상댓값, 대상 파일명 입력
  for cluster_num in range(clusters_num):
    # 개별 군집별 정보를 담을 데이터 초기화
    cluster_details[cluster_num] = {}
    cluster_details[cluster_num]['cluster'] = cluster_num

    # 위에서 구한 인덱스를 이용해 top n 피처 단어를 구함
    top_feature_indexes = centroid_feature_ordered_ind[cluster_num, :top_n_features]
    top_features = [feature_names[ind] for ind in top_feature_indexes]

    # top_feature_indexes 를 이용해 해당 피처 단어의 중심 위치 상댓값 구함
    top_feature_values = cluster_model.cluster_centers_[cluster_num, top_feature_indexes].tolist()

    # cluster_details 딕셔너리 객체에 개별 군집별 핵심단어와 중심위치 상댓값, 해당 파일명 입력
    cluster_details[cluster_num]['top_features'] = top_features
    cluster_details[cluster_num]['top_features_value'] = top_feature_values
    filenames = cluster_data[cluster_data['cluster_label'] == cluster_num]['filename']
    filenames = filenames.values.tolist()

    cluster_details[cluster_num]['filenames'] = filenames

  return cluster_details

# %%
def print_cluster_details(cluster_details):
  for cluster_num, cluster_detail in cluster_details.items():
    print('####### Cluster {0}'.format(cluster_num))
    print('Top features:', cluster_detail['top_features'])
    print('Reviews 파일명 :',cluster_detail['filenames'][:7])
    print('==================================================')

# %%
feature_names = tfidf_vect.get_feature_names_out() # 피처명 리스트 추출

cluster_details = get_cluster_details(cluster_model=km_cluster, cluster_data=document_df,
                                  feature_names=feature_names, clusters_num=3, top_n_features=10 )
print_cluster_details(cluster_details)
# Out:
# ####### Cluster 0
# Top features: ['screen', 'battery', 'keyboard', 'kindle', 'battery life', 'direction', 'life', 'voice', 'map', 'size']
# Reviews 파일명 : ['voice_garmin_nuvi_255W_gps', 'screen_ipod_nano_8gb', 'fonts_amazon_kindle', 'screen_garmin_nuvi_255W_gps', 'video_ipod_nano_8gb', 'satellite_garmin_nuvi_255W_gps', 'display_garmin_nuvi_255W_gps']
# ...
# ####### Cluster 1
# Top features: ['room', 'hotel', 'service', 'staff', 'food', 'location', 'bathroom', 'clean', 'price', 'parking']
# Reviews 파일명 : ['food_holiday_inn_london', 'bathroom_bestwestern_hotel_sfo', 'food_swissotel_chicago', 'staff_swissotel_chicago', 'free_bestwestern_hotel_sfo', 'rooms_bestwestern_hotel_sfo', 'location_holiday_inn_london']
# ...
# ####### Cluster 2
# Top features: ['interior', 'seat', 'mileage', 'performance', 'comfortable', 'gas', 'gas mileage', 'quality', 'transmission', 'car']
# ...
